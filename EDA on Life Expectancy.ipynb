# %%
# Importing the Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# To Display Maximum rows and columns

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)

# %%
data = pd.read_csv("LifeExpectancy.csv")
data.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0            263.0
# 1  Afghanistan  2014  Developing              59.9            271.0
# 2  Afghanistan  2013  Developing              59.9            268.0
# 3  Afghanistan  2012  Developing              59.5            272.0
# 4  Afghanistan  2011  Developing              59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624         65.0      1154
# 1             64     0.01               73.523582         62.0       492
# 2             66     0.01               73.219243         64.0       430
# 3             69     0.01               78.184215         67.0      2787
# 4             71     0.01                7.097109         68.0      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# ...

# %%
data.describe(include = 'all')
# Out:
#             Country         Year      Status  Life expectancy   \
# count          2938  2938.000000        2938       2928.000000
# unique          193          NaN           2               NaN
# top     El Salvador          NaN  Developing               NaN
# freq             16          NaN        2426               NaN
# mean            NaN  2007.518720         NaN         69.224932
# std             NaN     4.613841         NaN          9.523867
# min             NaN  2000.000000         NaN         36.300000
# 25%             NaN  2004.000000         NaN         63.100000
# 50%             NaN  2008.000000         NaN         72.100000
# 75%             NaN  2012.000000         NaN         75.700000
# max             NaN  2015.000000         NaN         89.000000
#
#         Adult Mortality  infant deaths      Alcohol  percentage expenditure  \
# count       2928.000000    2938.000000  2744.000000             2938.000000
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# #### In Data Analysis we will analyize to find out the below things
#
# - Missing Values
# - All the numerical features
# - Distribution of all the numerical variables/features
# - Categorical Variable/features
# - Cardinality of Categorical variables
# - Outliers
# - Relationship between independent and dependent feature( sales price)

# %% [markdown]
# #### Missing Valuse Relations

# %%
# we will try to find the percentage of missing values in the each feature
dataset= data.copy()
# we will get the all the feature with missing values
feature_nan = [feature for feature in dataset.columns if data[feature].isnull().sum()>1]

# missing value percentage the ecah featrue
for feature in feature_nan:
    print("The missing value percentage(%) in ",feature,data[feature].isnull().mean())
# Out:
# The missing value percentage(%) in  Life expectancy  0.0034036759700476512
# The missing value percentage(%) in  Adult Mortality 0.0034036759700476512
# The missing value percentage(%) in  Alcohol 0.06603131381892444
# The missing value percentage(%) in  Hepatitis B 0.18822328114363512
# The missing value percentage(%) in   BMI  0.011572498298162015
# The missing value percentage(%) in  Polio 0.006466984343090538
# The missing value percentage(%) in  Total expenditure 0.07692307692307693
# The missing value percentage(%) in  Diphtheria  0.006466984343090538
# The missing value percentage(%) in  GDP 0.1524846834581348
# The missing value percentage(%) in  Population 0.22191967324710687
# The missing value percentage(%) in   thinness  1-19 years 0.011572498298162015
# The missing value percentage(%) in   thinness 5-9 years 0.011572498298162015
# The missing value percentage(%) in  Income composition of resources 0.056841388699795777
# ...

# %% [markdown]
#  We can obsereve that in some features very less numer of missing value (less than 1 %) is present

# %%
#plot the missing values on the heatmap
plt.figure(figsize=(12,6))
sns.heatmap(data.isnull(),cbar = False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# This gives us more detail about the features with the missing values. Features like GDP,Population,Hepatitis B,Alcohol,total expenditure have high number of missing values.

# %%
# We can also see the count of missing value by count plot
for feature in feature_nan:
    dataset = data.copy()
    # Let's make a variable that indicates 1 if nan value present otherwise 0
    dataset[feature] = np.where(data[feature].isnull(),1,0)
    sns.countplot(x=feature,data = dataset,)
    plt.show()

# %%
# There are very less number of missing value in the tagetr feature (Life expectancy) so we can drop these records
print(data.shape)
data = data.dropna(subset = ['Life expectancy '])
data.reset_index(drop =True,inplace= True)
print(data.shape)
# Out:
# (2938, 22)
# (2928, 22)

# %% [markdown]
# ### Numerical Features Relation with Life Expentency
# 1. Continuous variable
# 2. Discrete Variable

# %%
num_features = [feature for feature in data.columns if data[feature].dtype != 'O']
data[num_features].head()
# Out:
#    Year  Life expectancy   Adult Mortality  infant deaths  Alcohol  \
# 0  2015              65.0            263.0             62     0.01
# 1  2014              59.9            271.0             64     0.01
# 2  2013              59.9            268.0             66     0.01
# 3  2012              59.5            272.0             69     0.01
# 4  2011              59.2            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   under-five deaths   \
# 0               71.279624         65.0      1154   19.1                  83
# 1               73.523582         62.0       492   18.6                  86
# 2               73.219243         64.0       430   18.1                  89
# 3               78.184215         67.0      2787   17.6                  93
# 4                7.097109         68.0      3013   17.2                  97
#
#    Polio  Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# ...

# %%
# Lets find the discrete features from the data
discrete_features = [feature for featue in data.columns if len(data[feature].unique()) < 25]
discrete_features
# Out:
# []

# %% [markdown]
# we don't have any discrete numerical feature

# %%
# lets see the relation between life expectancy and continuous numericalfeatures
for feature in num_features:
    dataset = data.copy()
    sns.jointplot(x='Life expectancy ',y = feature,data = dataset )
    plt.show()

# %%
# Avgerage life ecpectancy every year
dataset.groupby(['Year'])['Life expectancy '].mean().sort_values()
# Out:
# Year
# 2000    66.750273
# 2001    67.128962
# 2002    67.351366
# 2003    67.433333
# 2004    67.646448
# 2005    68.209290
# 2006    68.667760
# 2007    69.036066
# 2008    69.427869
# 2009    69.938251
# 2010    70.048634
# 2011    70.654098
# 2012    70.916940
# 2013    71.236066
# 2014    71.536612
# 2015    71.616940
# Name: Life expectancy , dtype: float64

# %% [markdown]
# Average Life expectancy is increasing with the years

# %%
# How does Infant and Adult mortality rates affect life expectancy?

sns.scatterplot(x = 'Adult Mortality',y ='Life expectancy ',data = data )
# Out:
# <AxesSubplot:xlabel='Adult Mortality', ylabel='Life expectancy '>

# %% [markdown]
# We can that as the Adult mortality increases ,life expectancy decreases. So there should be a negative correlation between them.

# %%
# How does Alcohol affect life expectancy? (Alcohol, recorded per capita (15+) consumption (in litres of pure alcohol))

sns.scatterplot(x = 'Alcohol',y ='Life expectancy ',data = data)
# Out:
# <AxesSubplot:xlabel='Alcohol', ylabel='Life expectancy '>

# %% [markdown]
# There is some positive correlation between alcohol consumption and life expectancy.
# We can observe the there are some outlies present.Because for few records those having high alcohol consumption have life expectancy more than 65 and  for few records those having low alcohol consumption(less than 5) have life expectancy less than 45.

# %%
# What is the impact of schooling on the lifespan of humans?
sns.regplot(x ='Schooling',y ='Life expectancy ',data = data,marker = '+',color = 'g')
# Out:
# <AxesSubplot:xlabel='Schooling', ylabel='Life expectancy '>

# %% [markdown]
# Schooling have a positive correlation with life expectancy.

# %%
# What is the impact of Immunization coverage on life Expectancy?
#Hepatitis B (HepB) immunization coverage among 1-year-olds (%)

sns.regplot(x ='Hepatitis B',y ='Life expectancy ',data = data,marker = '+',color = 'g')
# Out:
# <AxesSubplot:xlabel='Hepatitis B', ylabel='Life expectancy '>

# %% [markdown]
# We can obsserve that there is no linear relation between Immunization coverage and life Expectancy

# %%
# Lets see the relationship between life expectancy and expenditure
sns.regplot(x ='Total expenditure',y ='Life expectancy ',data = data,marker = '+',color = 'g')
# Out:
# <AxesSubplot:xlabel='Total expenditure', ylabel='Life expectancy '>

# %% [markdown]
# For Most of the total Expenditure are less than 10 and for them life expextancy approx range of  45 to 85

# %% [markdown]
# #### Lets see the distribution of the continuous features

# %%
for feature in num_features:
    dataset = data.copy()
    plt.hist(dataset[feature])
    plt.xlabel(feature)
    plt.ylabel("Count")
    plt.title(feature)
    plt.show()

# %% [markdown]
# We can observe the most of the features are not normally Distributed.So we have to convert it into the normal distribution in feature engineering

# %% [markdown]
# ### Outliers

# %%
for feature in num_features:
    data = data.copy()
    dataset.boxplot(column= feature)
    plt.ylabel(feature)
    plt.title(feature)
    plt.show()

# %% [markdown]
# We can see that their are outliers present in the some features. we will handle the outliers in the feature engineering.

# %% [markdown]
# ###  Categorical Features

# %%
cat_features = [feature for feature in data.columns if data[feature].dtype == 'O']
cat_features
# Out:
# ['Country', 'Status']

# %%
sns.countplot(x='Status',data =data)
# Out:
# <AxesSubplot:xlabel='Status', ylabel='count'>

# %% [markdown]
# We can see that most of the records belongs to the developing countries

# %%
data['Status'].value_counts()
# Out:
# Developing    2416
# Developed      512
# Name: Status, dtype: int64

# %%
len(data['Country'].unique())
# Out:
# 183

# %%
# Lets analyze the status and life expectancy 
sns.scatterplot(x = 'Status',y= 'Life expectancy ',data = data,color ='red')
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy '>

# %% [markdown]
# We can observe that for the developed countries life expectancy has high value (more than 65).

# %%
dataset = data.copy()
grp_data = dataset.groupby('Status')['Country']

grp_data.value_counts()
# Out:
# Status      Country
# Developed   Australia                                               16
#             Austria                                                 16
#             Belgium                                                 16
#             Bulgaria                                                16
#             Croatia                                                 16
#             Cyprus                                                  16
#             Czechia                                                 16
#             Denmark                                                 16
#             Germany                                                 16
#             Hungary                                                 16
#             Iceland                                                 16
#             Ireland                                                 16
#             Italy                                                   16
# ...

# %%
# lets analyze the country and life expectanct
plt.figure(figsize = (11,7))
sns.scatterplot(x = 'Country',y = 'Life expectancy ',data = data,hue = 'Status')
# Out:
# <AxesSubplot:xlabel='Country', ylabel='Life expectancy '>

# %%
sns.boxplot(x = 'Status', y = 'Life expectancy ',data = data)
# Out:
# <AxesSubplot:xlabel='Status', ylabel='Life expectancy '>

# %% [markdown]
#  We can observe that the median life expectancy for the developing coutries is near 70 and in the developed countries the median life expectancy is near 80. And there are some outliers w.r.t developing countries.

# %%
plt.figure(figsize = (10,30))
sns.boxplot(y = 'Country', x = 'Life expectancy ',data = data,orient="h")
# Out:
# <AxesSubplot:xlabel='Life expectancy ', ylabel='Country'>

# %% [markdown]
# We can observe the median life expectancy for the every country and also observe that some countries have the outliers present
